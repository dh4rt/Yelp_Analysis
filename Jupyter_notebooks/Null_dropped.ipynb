# %%
import pandas as pd
import json

null_removed_df = pd.read_csv("joined_data.csv")
null_removed_df.head()
# Out:
#               business_id                          name  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw  Turning Point of North Wales
# 1  gmjsEdUsKpj9Xxu6pdjH0g    The Voodoo Bone Lady Tours
# 2  uMvVYRgGNXf5boolA9HXTw        Shalimar Fine Jewelers
# 3  EQ-TZ2eeD_E0BHuvoaeG5Q                     Milktooth
# 4  lj-E32x9_FA7GmUrBGBEWg           Brio Italian Grille
#
#                         address          city state postal_code  review_count  \
# 0           1460 Bethlehem Pike   North Wales    PA       19454           169
# 1  201 St Charles Ave, Ste 2560   New Orleans    LA       70170           359
# 2             250 Westshore Plz         Tampa    FL       33609             8
# 3              534 Virginia Ave  Indianapolis    IN       46203          1379
# 4         1601 S Lindbergh Blvd      St Louis    MO       63131           366
#
#                 review_id  stars  \
# 0  KU_O5udG6zpxOg-VcAEodg    3.0
# 1  6AxgBCNX_PNTOxmbRSwcKQ    5.0
# 2  rGQRf8UafX7OTlMNN19I8A    5.0
# ...

# %%
null_removed_df.isna().sum()
# Out:
# business_id        0
# name               0
# address          110
# city               0
# state              0
# postal_code        0
# review_count       0
# review_id       2535
# stars           2535
# text            2535
# dtype: int64

# %%
null_count_df = pd.read_csv("joined_data_23557.csv")
null_count_df.head()
# Out:
#               business_id                             name  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw     Turning Point of North Wales
# 1  kxX2SOes4o-D3ZQBkiMRfA                            Zaika
# 2  gmjsEdUsKpj9Xxu6pdjH0g       The Voodoo Bone Lady Tours
# 3  gebiRewfieSdtt17PTW6Zg  Hibachi Steak House & Sushi Bar
# 4  uMvVYRgGNXf5boolA9HXTw           Shalimar Fine Jewelers
#
#                         address           city state postal_code  \
# 0           1460 Bethlehem Pike    North Wales    PA       19454
# 1                2481 Grant Ave   Philadelphia    PA       19114
# 2  201 St Charles Ave, Ste 2560    New Orleans    LA       70170
# 3                  502 State St  Santa Barbara    CA       93101
# 4             250 Westshore Plz          Tampa    FL       33609
#
#    review_count               review_id  stars  \
# 0           169  KU_O5udG6zpxOg-VcAEodg    3.0
# 1           181  AqPFMleE6RsU23_auESxiA    5.0
# 2           359  6AxgBCNX_PNTOxmbRSwcKQ    5.0
# ...

# %%
null_count_df.isna().sum()
# Out:
# business_id        0
# name               0
# address          441
# city               0
# state              0
# postal_code        0
# review_count       0
# review_id       9166
# stars           9166
# text            9166
# dtype: int64

# %%
null_count_df.count
# Out:
# <bound method DataFrame.count of                   business_id                             name  \
# 0      XQfwVwDr-v0ZS3_CbbE5Xw     Turning Point of North Wales
# 1      kxX2SOes4o-D3ZQBkiMRfA                            Zaika
# 2      gmjsEdUsKpj9Xxu6pdjH0g       The Voodoo Bone Lady Tours
# 3      gebiRewfieSdtt17PTW6Zg  Hibachi Steak House & Sushi Bar
# 4      uMvVYRgGNXf5boolA9HXTw           Shalimar Fine Jewelers
# ...                       ...                              ...
# 23552  kfqgGm2hJUj4NXEkkk1qIA      Indianapolis Motor Speedway
# 23553  pNcAnMQlDHDgTwUmlpYcQw                      Burger King
# 23554  Xw9d0xxZ2i1BuKP2rtXjxQ                         Leslie's
# 23555  0Zvrh9rCrThh1ZwGaTbDjA          Sound Stone Massage Spa
# 23556  HHrDpitzdKfcGcQvPWtSnw  Bob Hogue School of Real Estate
#
#                                   address              city state postal_code  \
# 0                     1460 Bethlehem Pike       North Wales    PA       19454
# ...

# %%
cleaned_count_df = null_count_df.dropna()

# %%
cleaned_count_df.count()
# Out:
# business_id     14314
# name            14314
# address         14314
# city            14314
# state           14314
# postal_code     14314
# review_count    14314
# review_id       14314
# stars           14314
# text            14314
# dtype: int64

# %%
cleaned_count_df.to_csv('cleaned_count.csv', index=False)

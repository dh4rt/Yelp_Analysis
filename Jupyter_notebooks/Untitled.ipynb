# %%
# Read in .csv file to verify columns
import pandas as pd

df = pd.read_csv('Cleaned_Business.csv')
df.head(10)
# Out:
#               business_id                      name  \
# 0  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1  tUFrWirKiKi_TAnsVWINQQ                    Target
# 2  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 3  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 4  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 5  n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
# 6  bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In
# 7  UJsufbvfyfONHeWdvAHKjA                 Marshalls
# 8  eEOYSgkmpB90uNA7lDOMRA     Vietnamese Food Truck
# 9  il_Ro8jwPlHresjw9EGmBg                   Denny's
#
#                                       address           city state  \
# 0             87 Grasso Plaza Shopping Center         Affton    MO
# 1                        5255 E Broadway Blvd         Tucson    AZ
# 2                                 935 Race St   Philadelphia    PA
# 3                               101 Walnut St     Green Lane    PA
# ...
